# %%
import pandas as pd 
df = pd.read_csv('/content/NLP_Q_T5_ALLEN_deberta-v3-large_for_QA.csv')
df
# Out:
#                              Question Using T5 Model  \
# 0           ['What is the term for a kind of what?']
# 1                                  ['What are gls?']
# 2  ['What is a programming language used for writ...
# 3  ['What type of languages are most programming ...
# 4  ['What share properties with natural languages?']
# 5     ['Who is the person who wrote the algorithm?']
# 6  ['What is the process by which programmers com...
# 7  ['What is a system of notation for writing com...
# 8  ['What is another name for lowlevel programmin...
#
#                        Answer (Key_phrases)  \
# 0                     ['computer language']
# 1        ['computer programming languages']
# 2                     ['computer programs']
# 3                      ['formal languages']
# 4  ['implementation programming languages']
# 5                            ['programmer']
# 6                           ['programming']
# 7                  ['programming language']
# ...

# %% [markdown]
# ##**Roberta_Answering_Questions**

# %%
# !pip install --quiet transformers

# %%
from transformers import RobertaTokenizer, RobertaForQuestionAnswering
import torch
Roberta_Answering_Questions = []
tokenizer = RobertaTokenizer.from_pretrained("deepset/roberta-base-squad2")
model = RobertaForQuestionAnswering.from_pretrained("deepset/roberta-base-squad2")
# for i in range(df['Allen_Answers'].size):
question, text = df['Question Using T5 Model'][0],df['Context'][0]
inputs = tokenizer(question, text, return_tensors="pt")
with torch.no_grad():
    outputs = model(**inputs)

answer_start_index = outputs.start_logits.argmax()
answer_end_index = outputs.end_logits.argmax()

predict_answer_tokens = inputs.input_ids[0, answer_start_index : answer_end_index + 1]
Roberta_Answering_Questions.append(tokenizer.decode(predict_answer_tokens))

# %%
Roberta_Answering_Questions
# Out:
# [' computer language']

# %%
# def Roberta_FN (question,text):
#   tokenizer = RobertaTokenizer.from_pretrained("deepset/roberta-base-squad2")
#   model = RobertaForQuestionAnswering.from_pretrained("deepset/roberta-base-squad2")
#   inputs = tokenizer(question, text, return_tensors="pt")
#   with torch.no_grad():
#       outputs = model(*inputs)

#   answer_start_index = outputs.start_logits.argmax()
#   answer_end_index = outputs.end_logits.argmax()

#   predict_answer_tokens = inputs.input_ids[0, answer_start_index : answer_end_index + 1]
  
#   return (tokenizer.decode(predict_answer_tokens))
