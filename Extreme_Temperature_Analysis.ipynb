# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Environment_Temperature_change_E_All_Data_NOFLAG.csv', encoding='Latin-1')

# %%
df.head()
# Out:
#    Area Code         Area  Months Code    Months  Element Code  \
# 0          2  Afghanistan         7001   January          7271
# 1          2  Afghanistan         7001   January          6078
# 2          2  Afghanistan         7002  February          7271
# 3          2  Afghanistan         7002  February          6078
# 4          2  Afghanistan         7003     March          7271
#
#               Element Unit  Y1961  Y1962  Y1963  ...  Y2010  Y2011  Y2012  \
# 0  Temperature change   °C  0.777  0.062  2.744  ...  3.601  1.179 -0.583
# 1  Standard Deviation   °C  1.950  1.950  1.950  ...  1.950  1.950  1.950
# 2  Temperature change   °C -1.743  2.465  3.919  ...  1.212  0.321 -3.201
# 3  Standard Deviation   °C  2.597  2.597  2.597  ...  2.597  2.597  2.597
# 4  Temperature change   °C  0.516  1.336  0.403  ...  3.390  0.748 -0.527
#
#    Y2013  Y2014  Y2015  Y2016  Y2017  Y2018  Y2019
# 0  1.233  1.755  1.943  3.416  1.201  1.996  2.951
# 1  1.950  1.950  1.950  1.950  1.950  1.950  1.950
# 2  1.494 -3.187  2.699  2.251 -0.323  2.705  0.086
# 3  2.597  2.597  2.597  2.597  2.597  2.597  2.597
# 4  2.246 -0.076 -0.497  2.296  0.834  4.418  0.234
#
# [5 rows x 66 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9656 entries, 0 to 9655
# Data columns (total 66 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     9656 non-null   int64
#  1   Area          9656 non-null   object
#  2   Months Code   9656 non-null   int64
#  3   Months        9656 non-null   object
#  4   Element Code  9656 non-null   int64
#  5   Element       9656 non-null   object
#  6   Unit          9656 non-null   object
#  7   Y1961         8287 non-null   float64
#  8   Y1962         8322 non-null   float64
#  9   Y1963         8294 non-null   float64
#  10  Y1964         8252 non-null   float64
#  11  Y1965         8281 non-null   float64
#  12  Y1966         8364 non-null   float64
#  13  Y1967         8347 non-null   float64
#  14  Y1968         8345 non-null   float64
#  15  Y1969         8326 non-null   float64
#  16  Y1970         8308 non-null   float64
#  17  Y1971         8303 non-null   float64
#  18  Y1972         8323 non-null   float64
#  19  Y1973         8394 non-null   float64
#  20  Y1974         8374 non-null   float64
#  21  Y1975         8280 non-null   float64
#  22  Y1976         8209 non-null   float64
#  23  Y1977         8257 non-null   float64
#  24  Y1978         8327 non-null   float64
#  25  Y1979         8290 non-null   float64
#  26  Y1980         8283 non-null   float64
#  27  Y1981         8276 non-null   float64
#  28  Y1982         8237 non-null   float64
#  29  Y1983         8205 non-null   float64
#  30  Y1984         8259 non-null   float64
#  31  Y1985         8216 non-null   float64
#  32  Y1986         8268 non-null   float64
#  33  Y1987         8284 non-null   float64
#  34  Y1988         8273 non-null   float64
#  35  Y1989         8257 non-null   float64
#  36  Y1990         8239 non-null   float64
#  37  Y1991         8158 non-null   float64
#  38  Y1992         8354 non-null   float64
#  39  Y1993         8315 non-null   float64
#  40  Y1994         8373 non-null   float64
#  41  Y1995         8409 non-null   float64
#  42  Y1996         8439 non-null   float64
#  43  Y1997         8309 non-null   float64
#  44  Y1998         8370 non-null   float64
#  45  Y1999         8324 non-null   float64
#  46  Y2000         8342 non-null   float64
#  47  Y2001         8241 non-null   float64
#  48  Y2002         8312 non-null   float64
#  49  Y2003         8390 non-null   float64
#  50  Y2004         8415 non-null   float64
#  51  Y2005         8424 non-null   float64
#  52  Y2006         8503 non-null   float64
#  53  Y2007         8534 non-null   float64
#  54  Y2008         8475 non-null   float64
#  55  Y2009         8419 non-null   float64
#  56  Y2010         8435 non-null   float64
#  57  Y2011         8437 non-null   float64
#  58  Y2012         8350 non-null   float64
#  59  Y2013         8427 non-null   float64
#  60  Y2014         8377 non-null   float64
#  61  Y2015         8361 non-null   float64
#  62  Y2016         8348 non-null   float64
#  63  Y2017         8366 non-null   float64
#  64  Y2018         8349 non-null   float64
#  65  Y2019         8365 non-null   float64
# dtypes: float64(59), int64(3), object(4)
# memory usage: 4.9+ MB

# %%
df = df[df['Element'] =='Temperature change']

# %%
df = df.fillna(0)

# %%
df.columns
# Out:
# Index(['Area Code', 'Area', 'Months Code', 'Months', 'Element Code', 'Element',
#        'Unit', 'Y1961', 'Y1962', 'Y1963', 'Y1964', 'Y1965', 'Y1966', 'Y1967',
#        'Y1968', 'Y1969', 'Y1970', 'Y1971', 'Y1972', 'Y1973', 'Y1974', 'Y1975',
#        'Y1976', 'Y1977', 'Y1978', 'Y1979', 'Y1980', 'Y1981', 'Y1982', 'Y1983',
#        'Y1984', 'Y1985', 'Y1986', 'Y1987', 'Y1988', 'Y1989', 'Y1990', 'Y1991',
#        'Y1992', 'Y1993', 'Y1994', 'Y1995', 'Y1996', 'Y1997', 'Y1998', 'Y1999',
#        'Y2000', 'Y2001', 'Y2002', 'Y2003', 'Y2004', 'Y2005', 'Y2006', 'Y2007',
#        'Y2008', 'Y2009', 'Y2010', 'Y2011', 'Y2012', 'Y2013', 'Y2014', 'Y2015',
#        'Y2016', 'Y2017', 'Y2018', 'Y2019'],
#       dtype='object')

# %%
df=df.melt(id_vars=['Area Code', 'Area', 'Months Code', 'Months', 'Element Code', 'Element',
       'Unit'],var_name='Year', value_name='Temp Change')
df.head()
# Out:
#    Area Code         Area  Months Code    Months  Element Code  \
# 0          2  Afghanistan         7001   January          7271
# 1          2  Afghanistan         7002  February          7271
# 2          2  Afghanistan         7003     March          7271
# 3          2  Afghanistan         7004     April          7271
# 4          2  Afghanistan         7005       May          7271
#
#               Element Unit   Year  Temp Change
# 0  Temperature change   °C  Y1961        0.777
# 1  Temperature change   °C  Y1961       -1.743
# 2  Temperature change   °C  Y1961        0.516
# 3  Temperature change   °C  Y1961       -1.709
# 4  Temperature change   °C  Y1961        1.412

# %%
df['Unit'].value_counts()
# Out:
# °C    284852
# Name: Unit, dtype: int64

# %%
df.drop(['Months Code','Element Code', 'Unit'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Area Code         Area    Months             Element   Year  Temp Change
# 0          2  Afghanistan   January  Temperature change  Y1961        0.777
# 1          2  Afghanistan  February  Temperature change  Y1961       -1.743
# 2          2  Afghanistan     March  Temperature change  Y1961        0.516
# 3          2  Afghanistan     April  Temperature change  Y1961       -1.709
# 4          2  Afghanistan       May  Temperature change  Y1961        1.412

# %%
df['Year'] = df['Year'].str[1:].astype('str')
df
# Out:
#         Area Code         Area               Months             Element  Year  \
# 0               2  Afghanistan              January  Temperature change  1961
# 1               2  Afghanistan             February  Temperature change  1961
# 2               2  Afghanistan                March  Temperature change  1961
# 3               2  Afghanistan                April  Temperature change  1961
# 4               2  Afghanistan                  May  Temperature change  1961
# ...           ...          ...                  ...                 ...   ...
# 284847       5873         OECD          DecJanFeb  Temperature change  2019
# 284848       5873         OECD          MarAprMay  Temperature change  2019
# 284849       5873         OECD          JunJulAug  Temperature change  2019
# 284850       5873         OECD          SepOctNov  Temperature change  2019
# 284851       5873         OECD  Meteorological year  Temperature change  2019
#
#         Temp Change
# 0             0.777
# 1            -1.743
# 2             0.516
# 3            -1.709
# 4             1.412
# ...             ...
# 284847        1.527
# 284848        1.352
# 284849        1.078
# 284850        1.233
# 284851        1.297
#
# [284852 rows x 6 columns]

# %%
df['Months'].unique()
# Out:
# array(['January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December',
#        'Dec\x96Jan\x96Feb', 'Mar\x96Apr\x96May', 'Jun\x96Jul\x96Aug',
#        'Sep\x96Oct\x96Nov', 'Meteorological year'], dtype=object)

# %%
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July',
       'August', 'September', 'October', 'November', 'December']

# %%
df = df[df['Months'].isin(months)]

# %%
df['Months'].unique()
# Out:
# array(['January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December'],
#       dtype=object)

# %%
df = df.groupby(['Area', 'Year']).mean().reset_index()

# %%
df.head()
# Out:
#           Area  Year  Area Code  Temp Change
# 0  Afghanistan  1961        2.0     0.072750
# 1  Afghanistan  1962        2.0    -0.229833
# 2  Afghanistan  1963        2.0     0.891583
# 3  Afghanistan  1964        2.0    -0.980000
# 4  Afghanistan  1965        2.0     0.010000

# %%
df['Year'] = pd.to_datetime(df['Year'])
df = df.sort_values('Year',ascending=True)
df['Year'] = df['Year'].dt.strftime('%m/%d/%Y')

# %%
df.head()
# Out:
#                    Area        Year  Area Code  Temp Change
# 0           Afghanistan  01/01/1961        2.0     0.072750
# 11446            Panama  01/01/1961      166.0     0.000000
# 11505  Papua New Guinea  01/01/1961      168.0    -0.218167
# 11564          Paraguay  01/01/1961      169.0     0.559917
# 1652              Benin  01/01/1961       53.0    -0.255667

# %%
df
# Out:
#                    Area        Year  Area Code  Temp Change
# 0           Afghanistan  01/01/1961        2.0     0.072750
# 11446            Panama  01/01/1961      166.0     0.000000
# 11505  Papua New Guinea  01/01/1961      168.0    -0.218167
# 11564          Paraguay  01/01/1961      169.0     0.559917
# 1652              Benin  01/01/1961       53.0    -0.255667
# ...                 ...         ...        ...          ...
# 11091              OECD  01/01/2019     5873.0     1.317750
# 11150           Oceania  01/01/2019     5500.0     1.448333
# 11209              Oman  01/01/2019      221.0     0.798333
# 10855   Northern Africa  01/01/2019     5103.0     1.247333
# 16755          Zimbabwe  01/01/2019      181.0     1.230083
#
# [16756 rows x 4 columns]

# %%
top_10 = df.groupby('Area').sum().sort_values('Temp Change', ascending=False)[:10].reset_index()['Area']
bottom_10 = df.groupby('Area').sum().sort_values('Temp Change', ascending=True)[:10].reset_index()['Area']

# %%
top_10
# Out:
# 0                          Mongolia
# 1    Svalbard and Jan Mayen Islands
# 2                            Gambia
# 3                           Morocco
# 4                     Guinea-Bissau
# 5                           Tunisia
# 6                        Mauritania
# 7                    Eastern Europe
# 8                           Austria
# 9                           Senegal
# Name: Area, dtype: object

# %%
bottom_10
# Out:
# 0                              Nauru
# 1                   Pitcairn Islands
# 2                      Midway Island
# 3        Falkland Islands (Malvinas)
# 4                       Yugoslav SFR
# 5    Pacific Islands Trust Territory
# 6                   Marshall Islands
# 7                          Singapore
# 8                     Czechoslovakia
# 9                               Niue
# Name: Area, dtype: object

# %%
countries = top_10.append(bottom_10)

# %%
df = df[df['Area'].isin(countries)]

# %%
import plotly.express as px

px.bar(df,x='Temp Change',y='Area',animation_frame='Year', hover_name='Temp Change',
      range_x=[-3.5,5.5], color='Area')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4a61df27-ffa8-4628-933a-abd471874f5f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4a61df27-ffa8-4628-933a-abd471874f5f")) {                    Plotly.newPlot(                        "4a61df27-ffa8-4628-933a-abd471874f5f",                        [{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Area=%{y}<br>Year=01/01/1961<br>Temp Change=%{x}<extra></extra>","hovertext":[0.6144166666666666],"legendgroup":"Pitcairn Islands","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Pitcairn Islands","offsetgroup":"Pitcairn Islands","orientation":"h","showlegend":true,"textposition":"auto","x":[0.6144166666666666],"xaxis":"x","y":["Pitcairn Islands"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Area=%{y}<br>Year=01/01/1961<br>Temp Change=%{x}<extra></extra>","hovertext":[0.59475],"legendgroup":"Yugoslav SFR","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Yugoslav SFR","offsetgroup":"Yugoslav SFR","orientation":"h","showlegend":true,"textposition":"auto","x":[0.59475],"xaxis":"x","y":["Yugoslav SFR"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Area=%{y}<br>Year=01/01/1961<br>Temp Change=%{x}<extra></extra>","hovertext":[0.18358333333333335],"legendgroup":"Niue","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Niue","offsetgroup":"Niue","orientation":"h","showlegend":true,"textposition":"auto","x":[0.18358333333333335],"xaxis":"x","y":["Niue"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Area=%{y}<br>Year=01/01/1961<br>Temp Change=%{x}<extra></extra>","hovertext":[-0.003583333333333339],"legendgroup":"Pacific Islands Trust Territory","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Pacific Islands Trust Territory","offsetgroup":"Pacific Islands Trust Territory","orientation":"h","showlegend":true,"textposition":"auto","x":[-0.003583333333333339],"xaxis":"x","y":["Pacific Islands Trust Territory"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Area=%{y}<br>Year=01/01/1961<br>Temp Change=%{x}<extra></extra>","hovertext":[0.3861666666666667],"legendgroup":"Svalbard and Jan Mayen Islands","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Svalbard and Jan Mayen Islands","offsetgroup":"Svalbard and Jan Mayen Islands","orientation":"h","showlegend":true,"textposition":"auto","x":[0.3861666666666667],"xaxis":"x","y":["Svalbard and Jan Mayen Islands"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Area=%{y}<br>Year=01/01/1961<br>Temp Change=%{x}<extra></extra>","hovertext":[0.3959166666666667],"legendgroup":"Tunisia","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Tunisia","offsetgroup":"Tunisia","orientation":"h","showlegend":true,"textposition":"auto","x":[0.3959166666666667],"xaxis":"x","y":["Tunisia"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Area=%{y}<br>Year=01/01/1961<br>Temp Change=%{x}<extra></extra>","hovertext":[-0.1739166666666667],"legendgroup":"Senegal","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Senegal","offsetgroup":"Senegal","orientation":"h","showlegend":true,"textposition":"auto","x":[-0.1739166666666667],"xaxis":"x","y":["Senegal"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Area=%{y}<br>Year=01/01/1961<br>Temp Change=%{x}<extra></extra>","hovertext":[0.025083333333333336],"legendgroup":"Singapore","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Singapore","offsetgroup":"Singa ...
